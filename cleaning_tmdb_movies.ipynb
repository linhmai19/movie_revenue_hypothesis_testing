# %% [markdown]
# # Data Cleaning for tmdb.movies.csv

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Import dataset

# %%
tmdb_movie = pd.read_csv('data/tmdb.movies.csv')

# %% [markdown]
# ## Preview general information about the dataset

# %%
# Shape of the dataset: rows and columns
print(tmdb_movie.shape)
# Check for NaN values
print(tmdb_movie.isna().sum())
# Preview the dataframe
tmdb_movie.head()
# Out:
# (26517, 10)
# Unnamed: 0           0
# genre_ids            0
# id                   0
# original_language    0
# original_title       0
# popularity           0
# release_date         0
# title                0
# vote_average         0
# vote_count           0
# dtype: int64
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186

# %% [markdown]
# ## Data cleaning process

# %%
#Remove the 'unnamed' column and set 'id' column as index
tmdb_movie = tmdb_movie.drop('Unnamed: 0', 1)
tmdb_movie.set_index('id', inplace=True)
tmdb_movie.head()
# Out:
#                  genre_ids original_language  \
# id
# 12444      [12, 14, 10751]                en
# 10191  [14, 12, 16, 10751]                en
# 10138        [12, 28, 878]                en
# 862        [16, 35, 10751]                en
# 27205        [28, 878, 12]                en
#
#                                      original_title  popularity release_date  \
# id
# 12444  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 10191                      How to Train Your Dragon      28.734   2010-03-26
# 10138                                    Iron Man 2      28.515   2010-05-07
# 862                                       Toy Story      28.005   1995-11-22
# 27205                                     Inception      27.920   2010-07-16
#
#                                               title  vote_average  vote_count
# id
# 12444  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 10191                      How to Train Your Dragon           7.7        7610
# 10138                                    Iron Man 2           6.8       12368
# 862                                       Toy Story           7.9       10174
# 27205                                     Inception           8.3       22186

# %%
# Change the type of 'release_date' column from object to datetime 
tmdb_movie['release_date'] = pd.to_datetime(tmdb_movie['release_date'])
print(tmdb_movie['release_date'].dtype)
# Out:
# datetime64[ns]

# %%
#Drop unnecessary columns 
tmdb_movie = tmdb_movie.drop(['genre_ids', 'original_language'], axis=1).copy()

# %%
#Choose only recent movies: from 2000 to 2018
movies_from_2000_2018 = tmdb_movie[(tmdb_movie['release_date'] > '2000-01-01') 
                                      & (tmdb_movie['release_date'] <= '2018-12-31')].copy()
movies_from_2000_2018
# Out:
#                                            original_title  popularity  \
# id
# 12444        Harry Potter and the Deathly Hallows: Part 1      33.533
# 10191                            How to Train Your Dragon      28.734
# 10138                                          Iron Man 2      28.515
# 27205                                           Inception      27.920
# 32657   Percy Jackson & the Olympians: The Lightning T...      26.691
# ...                                                   ...         ...
# 488143                              Laboratory Conditions       0.600
# 485975                                    _EXHIBIT_84xxx_       0.600
# 381231                                       The Last One       0.600
# 366854                                       Trailer Made       0.600
# 309885                                         The Church       0.600
#
#        release_date                                              title  \
# id
# 12444    2010-11-19       Harry Potter and the Deathly Hallows: Part 1
# 10191    2010-03-26                           How to Train Your Dragon
# 10138    2010-05-07                                         Iron Man 2
# 27205    2010-07-16                                          Inception
# 32657    2010-02-11  Percy Jackson & the Olympians: The Lightning T...
# ...             ...                                                ...
# 488143   2018-10-13                              Laboratory Conditions
# 485975   2018-05-01                                    _EXHIBIT_84xxx_
# 381231   2018-10-01                                       The Last One
# 366854   2018-06-22                                       Trailer Made
# 309885   2018-10-05                                         The Church
#
#         vote_average  vote_count
# id
# 12444            7.7       10788
# 10191            7.7        7610
# 10138            6.8       12368
# 27205            8.3       22186
# 32657            6.1        4229
# ...              ...         ...
# 488143           0.0           1
# 485975           0.0           1
# 381231           0.0           1
# 366854           0.0           1
# 309885           0.0           1
#
# [26334 rows x 6 columns]

# %%
#check the missing values again in movie_from_2000_2018 dataframe in each column
movies_from_2000_2018.isna().sum()
# Out:
# original_title    0
# popularity        0
# release_date      0
# title             0
# vote_average      0
# vote_count        0
# dtype: int64

# %%
#Extract the month and the day of the week from 'release_date' column and make them into 2 new columns
movies_from_2000_2018['month'] = pd.DatetimeIndex(movies_from_2000_2018['release_date']).month
movies_from_2000_2018['day_of_week'] = movies_from_2000_2018['release_date'].dt.day_name()
movies_from_2000_2018.head()
# Out:
#                                           original_title  popularity  \
# id
# 12444       Harry Potter and the Deathly Hallows: Part 1      33.533
# 10191                           How to Train Your Dragon      28.734
# 10138                                         Iron Man 2      28.515
# 27205                                          Inception      27.920
# 32657  Percy Jackson & the Olympians: The Lightning T...      26.691
#
#       release_date                                              title  \
# id
# 12444   2010-11-19       Harry Potter and the Deathly Hallows: Part 1
# 10191   2010-03-26                           How to Train Your Dragon
# 10138   2010-05-07                                         Iron Man 2
# 27205   2010-07-16                                          Inception
# 32657   2010-02-11  Percy Jackson & the Olympians: The Lightning T...
#
#        vote_average  vote_count  month day_of_week
# id
# 12444           7.7       10788     11      Friday
# 10191           7.7        7610      3      Friday
# 10138           6.8       12368      5      Friday
# 27205           8.3       22186      7      Friday
# 32657           6.1        4229      2    Thursday

# %% [markdown]
# ## Save the cleaned dataframe as a new CSV file

# %%
movies_from_2000_2018.to_csv('data/cleaned_tmdb_movie.csv')
